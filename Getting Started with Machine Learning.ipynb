# %% [markdown]
# # Chapter 1: Data Frames

# %%
import pandas as pd

df = pd.read_csv('results.csv')
df.shape
df
# Out:
#              date            home_team           away_team  home_score  \
# 0      1872-11-30             Scotland             England           0
# 1      1873-03-08              England            Scotland           4
# 2      1874-03-07             Scotland             England           2
# 3      1875-03-06              England            Scotland           2
# 4      1876-03-04             Scotland             England           3
# 5      1876-03-25             Scotland               Wales           4
# 6      1877-03-03              England            Scotland           1
# 7      1877-03-05                Wales            Scotland           0
# 8      1878-03-02             Scotland             England           7
# 9      1878-03-23             Scotland               Wales           9
# 10     1879-01-18              England               Wales           2
# 11     1879-04-05              England            Scotland           5
# ...

# %%
df.describe()
# Out:
#          home_score    away_score
# count  41540.000000  41540.000000
# mean       1.745643      1.187819
# std        1.753444      1.405511
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df.values
# Out:
# array([['1872-11-30', 'Scotland', 'England', ..., 'Glasgow', 'Scotland',
#         False],
#        ['1873-03-08', 'England', 'Scotland', ..., 'London', 'England',
#         False],
#        ['1874-03-07', 'Scotland', 'England', ..., 'Glasgow', 'Scotland',
#         False],
#        ...,
#        ['2019-11-19', 'Malaysia', 'Indonesia', ..., 'Kuala Lumpur',
#         'Malaysia', False],
#        ['2019-11-19', 'Turkmenistan', 'Sri Lanka', ..., 'Ashgabat',
#         'Turkmenistan', False],
#        ['2019-11-19', 'Lebanon', 'North Korea', ..., 'Beirut', 'Lebanon',
#         False]], dtype=object)

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
music_data = pd.read_csv('shopping.csv')

# %% [markdown]
# ## Preparing Data

# %% [markdown]
# ### Split the Data into Training/ Test Sets

# %%
# X is the Input Data
X = music_data.drop(columns='style')
X
# Out:
#     age  gender
# 0    16       1
# 1    18       1
# 2    19       1
# 3    20       1
# 4    23       1
# 5    25       1
# 6    26       1
# 7    29       1
# 8    30       1
# 9    31       1
# 10   33       1
# 11   37       1
# 12   15       0
# 13   18       0
# 14   20       0
# 15   20       0
# 16   21       0
# 17   25       0
# 18   26       0
# 19   27       0
# 20   30       0
# 21   31       0
# 22   34       0
# 23   35       0

# %%
# y is the Output Data
y = music_data['style']
y
# Out:
# 0             Streetwear
# 1             Streetwear
# 2             Streetwear
# 3             Streetwear
# 4                 Casual
# 5                 Casual
# 6                 Dapper
# 7                 Dapper
# 8                 Dapper
# 9                  Suite
# 10                 Suite
# 11                 Suite
# 12             Colourful
# 13             Colourful
# 14             Colourful
# 15             Colourful
# 16         Sophisticated
# 17         Sophisticated
# 18       Business Casual
# 19       Business Casual
# 20       Business Casual
# 21    Formal Office Wear
# 22    Formal Office Wear
# 23    Formal Office Wear
# Name: style, dtype: object

# %% [markdown]
# ## Create a Model Using an Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X, y)
music_data
# Out:
#     age  gender               style
# 0    16       1          Streetwear
# 1    18       1          Streetwear
# 2    19       1          Streetwear
# 3    20       1          Streetwear
# 4    23       1              Casual
# 5    25       1              Casual
# 6    26       1              Dapper
# 7    29       1              Dapper
# 8    30       1              Dapper
# 9    31       1               Suite
# 10   33       1               Suite
# 11   37       1               Suite
# 12   15       0           Colourful
# 13   18       0           Colourful
# 14   20       0           Colourful
# 15   20       0           Colourful
# 16   21       0       Sophisticated
# 17   25       0       Sophisticated
# 18   26       0     Business Casual
# 19   27       0     Business Casual
# 20   30       0     Business Casual
# 21   31       0  Formal Office Wear
# 22   34       0  Formal Office Wear
# 23   35       0  Formal Office Wear

# %%
predictions = model.predict([ [21, 1], [22, 0] ])

predictions
# Out:
# array(['Casual', 'Sophisticated'], dtype=object)

# %% [markdown]
# ## Measuring the Accuracy of Prediction Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
score = accuracy_score(y_test, predictions)

print('Prediction Accuracy Score is: ' + str(score))
# Out:
# Prediction Accuracy Score is: 0.6
